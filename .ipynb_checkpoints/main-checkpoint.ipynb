# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import chardet

class CSVToParquetConverter:
    def __init__(self, csv_file, parquet_file, chunksize=100_000):
        self.csv_file = csv_file
        self.parquet_file = parquet_file
        self.chunksize = chunksize
        self.codificacao = self.detectar_codificacao()
        self.parquet_writer = None

    def detectar_codificacao(self):
        with open(self.csv_file, 'rb') as f:
            resultado = chardet.detect(f.read(100000))
        print(f"Codificação detectada: {resultado['encoding']}")
        return resultado['encoding']

    def converter(self):
        try:
            csv_stream = pd.read_csv(
                self.csv_file, sep=';', chunksize=self.chunksize, low_memory=False, encoding=self.codificacao, on_bad_lines='skip'
            )

            for i, chunk in enumerate(csv_stream):
                print(f"Processando chunk {i}")
                if i == 0:
                    self.inicializar_parquet_writer(chunk)
                
                self.escrever_chunk(chunk)

            self.finalizar()

        except UnicodeDecodeError as e:
            print(f"Erro ao decodificar o arquivo: {e}")

    def inicializar_parquet_writer(self, chunk):
        parquet_schema = pa.Table.from_pandas(df=chunk).schema
        self.parquet_writer = pq.ParquetWriter(self.parquet_file, parquet_schema, compression='gzip')

    def escrever_chunk(self, chunk):
        table = pa.Table.from_pandas(chunk, schema=self.parquet_writer.schema)
        self.parquet_writer.write_table(table)

    def finalizar(self):
        if self.parquet_writer:
            self.parquet_writer.close()

# %%
# Exemplo de uso:
file_name = 'nome_do_arquivo'
csv_file = f'./files/csv/{file_name}.csv'
parquet_file = f'./files/parquet/{file_name}.parquet'

converter = CSVToParquetConverter(csv_file, parquet_file)
converter.converter()
# Out:
# Codificação detectada: ISO-8859-1
# Processando chunk 0

# %%
import pandas as pd

# Exemplo de uso:
parquet_file = f'./files/parquet/{file_name}.parquet'
df = pd.read_parquet(parquet_file)

df
# Out:
#      Atribuído a              Avaliação Bloqueada        CEP  \
# 0           None                   None      None  02710-000
# 1            uvw                   None      None       None
# 2            uvw                   None      None       None
# 3        M.PENHA  Prospect Sales - Gabi      None       None
# 4        M.PENHA                   None      None       None
# ...          ...                    ...       ...        ...
# 3794  Naara.Mota                   None      None       None
# 3795  Naara.Mota                   None      None       None
# 3796  Naara.Mota                   None      None  13347-680
# 3797  Naara.Mota                   None      None       None
# 3798  Naara.Mota                   None      None       None
#
#      CEP do Endereço de Entrega  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# ...                         ...
# 3794                       None
# 3795                       None
# 3796                  13347-680
# 3797                       None
# 3798                       None
#
#                               CNAE Atividade Secundária  \
# 0     32.50-7-01 - Fabricação de instrumentos não-el...
# 1     47.89-0-05 - Comércio varejista de produtos sa...
# 2                                                  None
# 3     33.19-8-00 - Manutenção e reparação de equipam...
# 4     25.43-8-00 - Fabricação de ferramentas\n28.25-...
# ...                                                 ...
# 3794                                               None
# 3795                                               None
# 3796  62.04-0-00 - Consultoria em tecnologia da info...
# 3797                                               None
# 3798                                               None
#
#                                              CNAE Grupo  \
# 0     26.6 - Fabricação de aparelhos eletromédicos e...
# 1                          81.2 - Atividades de limpeza
# 2                                                  None
# 3     22.2 - Fabricação de produtos de material plás...
# 4     28.6 - Fabricação de máquinas e equipamentos d...
# ...                                                 ...
# 3794                                      Pessoa Física
# 3795              85.5 - Atividades de apoio à educação
# 3796                 85.9 - Outras atividades de ensino
# 3797                           85.3 - Educação superior
# 3798  85.4 - Educação profissional de nível técnico ...
#
#                                          CNAE Subclasse                CNPJ  \
# 0     26 Fabricação De Equipamentos De Informática, ...  58.511.270/0001-47
# 1     81 Serviços Para Edifícios E Atividades Paisag...  54.148.523/0001-09
# 2                                                  None                None
# 3     22 Fabricação De Produtos De Borracha E De Mat...  13.829.701/0001-80
# 4              28 Fabricação De Máquinas E Equipamentos  56.995.681/0002-00
# ...                                                 ...                 ...
# 3794                                      Pessoa Física                None
# 3795                                        85 Educação  49.607.336/0001-06
# 3796                                        85 Educação  03.774.819/0075-30
# 3797                                        85 Educação  63.025.530/0001-04
# 3798                                        85 Educação  03.774.819/0019-23
#
#        CPF  ...     Status Telefone Alternativo  \
# 0     None  ...  Bloqueada                  NaN
# 1     None  ...      Ativa                  NaN
# 2     None  ...      Ativa                  NaN
# 3     None  ...      Ativa                  NaN
# 4     None  ...      Ativa                  NaN
# ...    ...  ...        ...                  ...
# 3794     x  ...      Ativa                  NaN
# 3795  None  ...      Ativa                  NaN
# 3796  None  ...      Ativa                  NaN
# 3797  None  ...      Ativa                  NaN
# 3798  None  ...      Ativa                  NaN
#
#                Telefone do Escritório Tem CBI?              Tipo  \
# 0                      (11) 2591-6000     None           Cliente
# 1                      (19) 3242-5947     None        Fornecedor
# 2                      (15) 3232-9211     None        Fornecedor
# 3                      (11) 3326-1823     None  Possível Cliente
# 4                      (19) 3879-8725     None  Possível Cliente
# ...                               ...      ...               ...
# 3794                             None     None        Patrocínio
# 3795                   (19) 3521-2777     None           Cliente
# 3796  (19) 3825-3450 / (11) 3146-7480     None  Possível Cliente
# 3797   (11) 3091-3251/ (11) 3091-3070     None  Possível Cliente
# 3798                   (15) 3212-7400     None           Cliente
#
#      Tipo do Processo UF de Endereço de Entrega  \
# 0                None                      None
# 1                None                      None
# 2                None                      None
# 3                None                      None
# 4                None                      None
# ...               ...                       ...
# 3794             None                      None
# 3795             None                      None
# 3796             None                        SP
# 3797             None                      None
# 3798             None                      None
#
#                                   Website qtd chamados flag  \
# 0                                 http://               1.0
# 1              http://www.dmpragas.com.br               0.0
# 2              http://mhmnotebooks.com.br               0.0
# 3                                 http://               0.0
# 4     http://http://www.asvotec.com.br/br               0.0
# ...                                   ...               ...
# 3794                              http://               0.0
# 3795                              http://               0.0
# 3796       http://indaiatuba.sp.senai.br/               0.0
# 3797                              http://               0.0
# 3798                              http://               0.0
#
#      &#039;Proprietários 1:&#039; (ID &#039;Contato&#039; relacionado)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3794                                                NaN
# 3795                                                NaN
# 3796                                                NaN
# 3797                                                NaN
# 3798                                                NaN
#
# [3799 rows x 80 columns]
